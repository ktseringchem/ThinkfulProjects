# %%
import pandas as pd
import numpy as np
from sklearn import tree
from sklearn import ensemble
#import pydotplus
#import graphviz
from IPython.display import Image
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.datasets import fetch_mldata
from sklearn.model_selection import train_test_split

mnist = pd.read_csv("RandomForesttemps.csv")

# %%
mnist
# Out:
#      year  month  day   week  temp_2  temp_1  average  actual  forecast_noaa  \
# 0    2016      1    1    Fri      45      45     45.6      45             43
# 1    2016      1    2    Sat      44      45     45.7      44             41
# 2    2016      1    3    Sun      45      44     45.8      41             43
# 3    2016      1    4    Mon      44      41     45.9      40             44
# 4    2016      1    5   Tues      41      40     46.0      44             46
# 5    2016      1    6    Wed      40      44     46.1      51             43
# 6    2016      1    7  Thurs      44      51     46.2      45             45
# 7    2016      1    8    Fri      51      45     46.3      48             43
# 8    2016      1    9    Sat      45      48     46.4      50             46
# 9    2016      1   10    Sun      48      50     46.5      52             45
# 10   2016      1   11    Mon      50      52     46.7      45             42
# ...

# %%
mnist_list = list(mnist.columns)
#mnist = np.array(mnist)

months = mnist[:, mnist_list.index('month')]
days = mnist[:, mnist_list.index('day')]
years = mnist[:, mnist_list.index('year')]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-4f0303eb8ac7> in <module>()
#       2 #mnist = np.array(mnist)
#       3
# ----> 4 months = mnist[:, mnist_list.index('month')]
#       5 days = mnist[:, mnist_list.index('day')]
#       6 years = mnist[:, mnist_list.index('year')]
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    1962             return self._getitem_multilevel(key)
#    1963         else:
# -> 1964             return self._getitem_column(key)
#    1965
#    1966     def _getitem_column(self, key):
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    1969         # get column
#    1970         if self.columns.is_unique:
# -> 1971             return self._get_item_cache(key)
#    1972
#    1973         # duplicate columns & possible reduce dimensionality
#
# ...

# %%
mnist.isnull().values.any()
# Out:
# False

# %%
# Descriptive statistics for each column
mnist.describe()

# %%
f, (ax1, ax2, ax3, ax4) = plt.subplots(1, 4, sharey='all', sharex='none', figsize=(18,6))

ax1.scatter(mnist['', AQMadrid['Price'], color='r')

ax2.scatter(AQMadrid['Bathrooms'], AQMadrid['Price'], color='b')

ax3.scatter(AQMadrid['SQFT'], AQMadrid['Price'], color='k')

ax4.scatter(AQMadrid['Price/SQFT'], AQMadrid['Price'], color='g')

plt.show()

# %%
# One-hot encode the data using pandas get_dummies
mnist = pd.get_dummies(mnist)
# Display the first 5 rows of the last 12 columns
mnist.head(20)

# %%
target = mnist.actual
features = mnist.drop(['actual', 'week'], axis=1)

# %%
# The baseline predictions are the historical averages
baseline_preds = test_X[:, mnist_list.index('average')]
# Baseline errors, and display average baseline error
baseline_errors = abs(baseline_preds - test_Y)
print('Average baseline error: ', round(np.mean(baseline_errors), 2))

# %%
#initialize the tree model
decision_tree = tree.DecisionTreeClassifier(
    criterion='entropy',
    max_features=1,
    max_depth=4
)


import time
start_time = time.clock()
#main()
print("--- %s seconds ---" % (time.time() - start_time))

cross_val_score(decision_tree, features, target, cv=10)

# %%
rfc = ensemble.RandomForestClassifier(n_estimators = 100, random_state = 42)

start_time = time.clock()
#main()
print("--- %s seconds ---" % (time.time() - start_time))
cross_val_score(rfc, features, target, cv=10)

# %%
# split data into test and traning
train_X, test_X, train_Y, test_Y = train_test_split( features, target, test_size=0.20, random_state=0)

# %%
# Instantiate model with 1000 decision trees
rfc = RandomForestRegressor(n_estimators = 100, random_state = 42)
# Train the model on training data
score = rfc.fit(train_X, train_Y).score(test_X, test_Y)
print(score)

# %%
score = decision_tree.fit(train_X, train_Y).score(test_X, test_Y)
print(score)
