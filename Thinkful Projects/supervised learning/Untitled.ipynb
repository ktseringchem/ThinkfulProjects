# %%
import numpy as np
import pandas as pd
import statistics
import matplotlib.pyplot as plt
df = pd.DataFrame()
df["age"] = [28,34,2,5,93,93, 45,23,82,12, 12, 25]

# %%
statistics.mode(df["age"])
(values, counts) = np.unique(df['age'], return_counts=True)
#ind = np.argmax(counts)
values[]
# Out:
#   File "<ipython-input-3-ab3fe0373c6b>", line 4
#     values[]
#            ^
# SyntaxError: invalid syntax

# %%
pop=pd.DataFrame()

# Then create two variables with mean = 60, one with a low standard
# deviation (sd=10) and one with a high standard deviation (sd=100).
pop['low_var']=np.random.normal(60, 10, 10000)
pop['high_var']=np.random.normal(60, 100, 10000)

# Finally, create histograms of the two variables.
pop.hist(layout=(4,1), sharex=True)
plt.show()

# Calculate and print the maximum and minimum values for each variable.
print(pop.max())
print(pop.min())
pop
# Out:
# low_var      97.816282
# high_var    443.323658
# dtype: float64
# low_var      21.861975
# high_var   -343.103068
# dtype: float64
#         low_var    high_var
# 0     51.185054   45.539411
# 1     49.464249   18.151268
# 2     57.541833  -48.112944
# 3     57.842336   18.382189
# 4     65.313829  243.564642
# 5     58.413194   41.692708
# 6     57.952750   65.111679
# 7     67.406827   -5.733493
# 8     48.768189   73.830338
# 9     62.453537   -8.332460
# 10    55.591043  100.188157
# 11    56.717460   59.925325
# 12    83.911217   36.173319
# 13    59.921098  -93.473525
# 14    46.577472  182.602071
# 15    61.642477  -84.230165
# 16    58.820426   90.052356
# 17    70.801019  120.328196
# 18    64.898560   -9.854519
# 19    53.190771  -39.733488
# 20    66.296937   75.785493
# 21    76.223875  -86.142956
# 22    71.091749   -3.826908
# 23    81.879482  -21.315265
# 24    48.508647  114.331204
# 25    61.683962  -25.389294
# 26    56.588068   16.925169
# 27    70.747339   48.523505
# 28    58.736629  174.243862
# 29    51.921004  159.676558
# ...         ...         ...
# 9970  64.878484   50.477723
# 9971  49.182784   66.517340
# 9972  62.808586   70.768061
# 9973  64.697112  -32.819249
# 9974  59.089975    2.746477
# 9975  55.272899    0.530481
# 9976  60.209961 -118.865125
# 9977  56.393431  211.819482
# 9978  72.880664   80.763519
# 9979  55.323186 -125.663159
# 9980  70.192023   20.141271
# 9981  61.552249   -8.627416
# 9982  47.802315  -37.955555
# 9983  62.414421  161.090382
# 9984  63.221780   63.281358
# 9985  75.028120  146.914845
# 9986  68.600363   56.854512
# 9987  90.275006   14.138035
# 9988  79.287890   13.157835
# 9989  66.827677 -108.772461
# 9990  52.896414   -1.149195
# 9991  56.656001  -43.121661
# 9992  62.616473  143.075365
# 9993  65.206818  129.766505
# 9994  66.728076  -32.011533
# 9995  71.874118   48.597990
# 9996  52.800978  170.535942
# 9997  60.024009  -54.802970
# 9998  59.894473 -119.263426
# 9999  47.259761  156.949190
#
# [10000 rows x 2 columns]

# %%
# Take a random sample of 100 observations from each variable
# and store it in a new dataframe.
sample=pd.DataFrame()
sample['low_var'] = np.random.choice(pop['low_var'], 1000)
sample['high_var']=np.random.choice(pop['high_var'], 1000)

# Again, visualize the data. Note that here we're using a pandas method to 
# create the histogram.
sample.hist()
plt.show()

# Check how well the sample replicates the population.
#sample.mean()
sample.std(ddof=1)
# Out:
# low_var      9.773140
# high_var    96.959739
# dtype: float64
