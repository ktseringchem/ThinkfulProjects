# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import scipy
import sklearn
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
import random
from sklearn.model_selection import cross_val_score
from sklearn.metrics import confusion_matrix
from sklearn.naive_bayes import BernoulliNB

# %%
review_raw = pd.read_csv('yelp_labelled.txt', delimiter= '\t', header=None)
review_raw.columns = ['message', 'sentement']
review_raw.head()
# Out:
#                                              message  sentement
# 0                           Wow... Loved this place.          1
# 1                                 Crust is not good.          0
# 2          Not tasty and the texture was just nasty.          0
# 3  Stopped by during the late May bank holiday of...          1
# 4  The selection on the menu was great and so wer...          1

# %%
keywords = [ 'only', 'back', 'very', 'over', 'food', 'took', 'horrible', 'don\'t', 'least', 'much', 'excuse', 'down', 'bad', 'any', 'sucks', 'final', 'worst', 'hate', 'hated', 'never','not', 'slow', 'nasty', 'angry', 'didn\'t', 'poor', 'no']

# %%
for key in keywords:
    # Note that we add spaces around the key so that we're getting the word,
    # not just pattern matching.
    review_raw[str(key)] = review_raw.message.str.contains(
        ' ' + str(key) + ' ',
        case=False
    )
    
review_raw['allcaps'] = review_raw.message.str.isupper()

data = review_raw[keywords + ['allcaps']]
target = review_raw['sentement']

# Instantiate our model and store it in a new variable.
bnb = BernoulliNB()

# %%
datatargetfold = pd.DataFrame()
datafold = data
targetfold = target
d={}
t={}
for i in range(0, 10):
    d['datafoldsample{}'.format(i)] = datafold.sample(n=100, replace=False)
    indexNum = d['datafoldsample{}'.format(i)].index.tolist()
    datafold = datafold.drop(indexNum)
    
    t['targetfoldsample{}'.format(i)] = targetfold.take(indexNum)

# %%
print(cross_val_score(bnb, data2, target, cv=10))
for sample in d:
    X_train = pd.DataFrame()
    Y_train = pd.DataFrame()
    for x in range(0, 10):
        if sample != 'datafoldsample{}'.format(x):
            X_train = X_train.append(d['datafoldsample{}'.format(x)])
            Y_train = pd.concat([Y_train, t['targetfoldsample{}'.format(x)]])
        else:
            X_test = d['datafoldsample{}'.format(x)]
            Y_test = t['targetfoldsample{}'.format(x)]
    
    #y_pred = bnb.fit(X_train, Y_train).predict(X_test)
    
    k = confusion_matrix(Y_test, y_pred)
    print('With 20% Holdout: ' + str(100*bnb.fit(X_train, Y_train).score(X_test, Y_test)))
    print(k)
    print('percentage of true positive: ' + str(100*k[0][0]/(k[0][0] + k[0][1])))
    print('percentage of true negative: ' + str(100*k[1][1]/(k[1][0] + k[1][1])) + '\n')
# Out:
# [ 0.72  0.64  0.71  0.59  0.65  0.61  0.66  0.62  0.6   0.66]
# With 20% Holdout: 67.0
# [[14 40]
#  [16 30]]
# percentage of true positive: 25.9259259259
# percentage of true negative: 65.2173913043
#
# With 20% Holdout: 65.0
# [[14 35]
#  [16 35]]
# percentage of true positive: 28.5714285714
# percentage of true negative: 68.6274509804
#
# With 20% Holdout: 69.0
# [[13 35]
#  [17 35]]
# percentage of true positive: 27.0833333333
# percentage of true negative: 67.3076923077
#
# With 20% Holdout: 70.0
# [[10 43]
#  [20 27]]
# percentage of true positive: 18.8679245283
# percentage of true negative: 57.4468085106
#
# With 20% Holdout: 70.0
# [[12 39]
#  [18 31]]
# percentage of true positive: 23.5294117647
# percentage of true negative: 63.2653061224
#
# With 20% Holdout: 66.0
# [[18 34]
#  [12 36]]
# C:\Users\ktser\Anaconda3\lib\site-packages\sklearn\utils\validation.py:578: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# percentage of true positive: 34.6153846154
# percentage of true negative: 75.0
#
# With 20% Holdout: 63.0
# [[16 31]
#  [14 39]]
# percentage of true positive: 34.0425531915
# percentage of true negative: 73.5849056604
#
# With 20% Holdout: 66.0
# [[12 30]
#  [18 40]]
# percentage of true positive: 28.5714285714
# percentage of true negative: 68.9655172414
#
# With 20% Holdout: 68.0
# [[14 40]
#  [16 30]]
# percentage of true positive: 25.9259259259
# percentage of true negative: 65.2173913043
#
# With 20% Holdout: 60.0
# [[20 30]
#  [10 40]]
# percentage of true positive: 40.0
# percentage of true negative: 80.0

# %%
keywords2 = [ 'only', 'very', 'over', 'don\'t', 'least', 'took', 'much', 'down', 'bad', 'any', 'hate', 'hated', 'never','not', 'didn\'t', 'no']

# %%
review_raw = pd.read_csv('yelp_labelled.txt', delimiter= '\t', header=None)
review_raw.columns = ['message', 'sentement']

for key in keywords2:
    # Note that we add spaces around the key so that we're getting the word,
    # not just pattern matching.
    review_raw[str(key)] = review_raw.message.str.contains(
        ' ' + str(key) + ' ',
        case=False
    )

data2 = review_raw[keywords2]

print(cross_val_score(bnb, data2, target, cv=10))

for sample in d:
    X_train = pd.DataFrame()
    Y_train = pd.DataFrame()
    for x in range(0, 10):
        if sample != 'datafoldsample{}'.format(x):
            X_train = X_train.append(d['datafoldsample{}'.format(x)])
            Y_train = pd.concat([Y_train, t['targetfoldsample{}'.format(x)]])
        else:
            X_test = d['datafoldsample{}'.format(x)]
            Y_test = t['targetfoldsample{}'.format(x)]
    
    #y_pred = bnb.fit(X_train, Y_train).predict(X_test)
    
    k = confusion_matrix(Y_test, y_pred)
    print('With 20% Holdout: ' + str(100*bnb.fit(X_train, Y_train).score(X_test, Y_test)))
    print(k)
    print('percentage of true positive: ' + str(100*k[0][0]/(k[0][0] + k[0][1])))
    print('percentage of true negative: ' + str(100*k[1][1]/(k[1][0] + k[1][1])) + '\n')
# Out:
# [ 0.72  0.64  0.71  0.59  0.65  0.61  0.66  0.62  0.6   0.66]
# With 20% Holdout: 67.0
# [[14 40]
#  [16 30]]
# percentage of true positive: 25.9259259259
# percentage of true negative: 65.2173913043
#
# With 20% Holdout: 65.0
# [[14 35]
#  [16 35]]
# percentage of true positive: 28.5714285714
# percentage of true negative: 68.6274509804
#
# With 20% Holdout: 69.0
# [[13 35]
#  [17 35]]
# percentage of true positive: 27.0833333333
# percentage of true negative: 67.3076923077
#
# With 20% Holdout: 70.0
# [[10 43]
#  [20 27]]
# percentage of true positive: 18.8679245283
# percentage of true negative: 57.4468085106
#
# With 20% Holdout: 70.0
# [[12 39]
#  [18 31]]
# percentage of true positive: 23.5294117647
# percentage of true negative: 63.2653061224
#
# With 20% Holdout: 66.0
# C:\Users\ktser\Anaconda3\lib\site-packages\sklearn\utils\validation.py:578: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [[18 34]
#  [12 36]]
# percentage of true positive: 34.6153846154
# percentage of true negative: 75.0
#
# With 20% Holdout: 63.0
# [[16 31]
#  [14 39]]
# percentage of true positive: 34.0425531915
# percentage of true negative: 73.5849056604
#
# With 20% Holdout: 66.0
# [[12 30]
#  [18 40]]
# percentage of true positive: 28.5714285714
# percentage of true negative: 68.9655172414
#
# With 20% Holdout: 68.0
# [[14 40]
#  [16 30]]
# percentage of true positive: 25.9259259259
# percentage of true negative: 65.2173913043
#
# With 20% Holdout: 60.0
# [[20 30]
#  [10 40]]
# percentage of true positive: 40.0
# percentage of true negative: 80.0

# %%
print(cross_val_score(bnb, data, target, cv=10))
for i in range(0 , 10):
    datahold = data.sample(n=100, replace=False)
    indexval = datahold.index.values.tolist()
    targethold = target.take(indexval)
    
    X_train, X_test, y_train, y_test = train_test_split(datahold, targethold, test_size=0.2, random_state=20)
    
    y_pred = bnb.fit(datahold, targethold).predict(datahold)
    
    k = confusion_matrix(targethold, y_pred)
    
    print('With 20% Holdout: ' + str(100*bnb.fit(X_train, y_train).score(X_test, y_test)))
    #print('Testing sample: ' + str(100*bnb.fit(X_train, y_train).score(X_train, y_train)))
    print(k)
    print('percentage of true positive: ' + str(100*k[0][0]/(k[0][0] + k[0][1])))
    print('percentage of true negative: ' + str(100*k[1][1]/(k[1][0] + k[1][1])) + '\n')
# Out:
# [ 0.72  0.62  0.72  0.59  0.67  0.64  0.69  0.66  0.62  0.66]
# With 20% Holdout: 65.0
# [[56  3]
#  [34  7]]
# percentage of true positive: 94.9152542373
# percentage of true negative: 17.0731707317
#
# With 20% Holdout: 80.0
# [[16 25]
#  [ 2 57]]
# percentage of true positive: 39.0243902439
# percentage of true negative: 96.6101694915
#
# With 20% Holdout: 65.0
# [[17 31]
#  [ 1 51]]
# percentage of true positive: 35.4166666667
# percentage of true negative: 98.0769230769
#
# With 20% Holdout: 75.0
# [[22 29]
#  [ 5 44]]
# percentage of true positive: 43.137254902
# percentage of true negative: 89.7959183673
#
# With 20% Holdout: 65.0
# [[20 32]
#  [ 2 46]]
# percentage of true positive: 38.4615384615
# percentage of true negative: 95.8333333333
#
# With 20% Holdout: 65.0
# [[15 28]
#  [ 3 54]]
# percentage of true positive: 34.8837209302
# percentage of true negative: 94.7368421053
#
# With 20% Holdout: 70.0
# [[27 28]
#  [ 2 43]]
# percentage of true positive: 49.0909090909
# percentage of true negative: 95.5555555556
#
# With 20% Holdout: 40.0
# [[21 32]
#  [ 6 41]]
# percentage of true positive: 39.6226415094
# percentage of true negative: 87.2340425532
#
# With 20% Holdout: 60.0
# [[53  1]
#  [36 10]]
# percentage of true positive: 98.1481481481
# percentage of true negative: 21.7391304348
#
# With 20% Holdout: 50.0
# [[17 25]
#  [ 1 57]]
# percentage of true positive: 40.4761904762
# percentage of true negative: 98.275862069

# %%
review_raw = pd.read_csv('yelp_labelled.txt', delimiter= '\t', header=None)

review_raw.columns = ['message', 'sentement']

review_raw.head()
# Out:
#                                              message  sentement
# 0                           Wow... Loved this place.          1
# 1                                 Crust is not good.          0
# 2          Not tasty and the texture was just nasty.          0
# 3  Stopped by during the late May bank holiday of...          1
# 4  The selection on the menu was great and so wer...          1

# %% [markdown]
# Above is evaluation of my first classifier model. The performance based on accuracy. There overfitting due to the difference in perforance of training and test data sets and the inconsistancy between the folds. Lot of the error is due to false positive, our feature set is more email as spam than ham. Although we are perdicting hams at very high percentage, we are letting in alot of spams, so I should focus more on feature engeneering to correctly perdict spams.

# %%
#keywords = [ 'only', 'back', 'very', 'over', 'food', 'took', 'horrible', 'don\'t', 'least', 'much', 'excuse', 'down', 'bad', 'any', 'sucks', 'final', 'worst', 'hate', 'hated', 'never','not', 'slow', 'nasty', 'angry', 'didn\'t', 'poor', 'no']
keywords2 = [ 'only', 'very', 'over', 'don\'t', 'least', 'took', 'much', 'down', 'bad', 'any', 'hate', 'hated', 'never','not', 'didn\'t', 'no']

# %%
for key in keywords2:
    # Note that we add spaces around the key so that we're getting the word,
    # not just pattern matching.
    review_raw[str(key)] = review_raw.message.str.contains(
        ' ' + str(key) + ' ',
        case=False
    )

data2 = review_raw[keywords2]
target = review_raw['sentement']

print(cross_val_score(bnb, data2, target2, cv=10))

for i in range(0 , 10):
    datahold = data2.sample(n=100, replace=False)
    indexval = datahold.index.values.tolist()
    targethold = target2.take(indexval)
    
    X_train, X_test, y_train, y_test = train_test_split(datahold, targethold, test_size=0.2, random_state=20)
    
    y_pred = bnb.fit(datahold, targethold).predict(datahold)
    
    k = confusion_matrix(targethold, y_pred)
    
    print('With 20% Holdout: ' + str(100*bnb.fit(X_train, y_train).score(X_test, y_test)))
    #print('Testing sample: ' + str(100*bnb.fit(X_train, y_train).score(X_train, y_train)))
    print(k)
    print('percentage of true positive: ' + str(100*k[0][0]/(k[0][0] + k[0][1])))
    print('percentage of true negative: ' + str(100*k[1][1]/(k[1][0] + k[1][1])) + '\n')
# Out:
# [ 0.52  0.56  0.45  0.54  0.51  0.49  0.49  0.53  0.48  0.51]
# With 20% Holdout: 50.0
# [[16 37]
#  [ 5 42]]
# percentage of true positive: 30.1886792453
# percentage of true negative: 89.3617021277
#
# With 20% Holdout: 40.0
# [[13 36]
#  [ 3 48]]
# percentage of true positive: 26.5306122449
# percentage of true negative: 94.1176470588
#
# With 20% Holdout: 40.0
# [[56  2]
#  [37  5]]
# percentage of true positive: 96.5517241379
# percentage of true negative: 11.9047619048
#
# With 20% Holdout: 30.0
# [[17 34]
#  [ 6 43]]
# percentage of true positive: 33.3333333333
# percentage of true negative: 87.7551020408
#
# With 20% Holdout: 40.0
# [[49  2]
#  [42  7]]
# percentage of true positive: 96.0784313725
# percentage of true negative: 14.2857142857
#
# With 20% Holdout: 30.0
# [[49  3]
#  [38 10]]
# percentage of true positive: 94.2307692308
# percentage of true negative: 20.8333333333
#
# With 20% Holdout: 45.0
# [[14 34]
#  [ 7 45]]
# percentage of true positive: 29.1666666667
# percentage of true negative: 86.5384615385
#
# With 20% Holdout: 50.0
# [[11 38]
#  [ 3 48]]
# percentage of true positive: 22.4489795918
# percentage of true negative: 94.1176470588
#
# With 20% Holdout: 45.0
# [[11 36]
#  [ 4 49]]
# percentage of true positive: 23.4042553191
# percentage of true negative: 92.4528301887
#
# With 20% Holdout: 50.0
# [[45  4]
#  [40 11]]
# percentage of true positive: 91.8367346939
# percentage of true negative: 21.568627451

# %% [markdown]
# For the second feature set I removed all the words that are not adverb. The result did not improve, overfitting is lager and the type of error contributing to over all error is random between the folds. The type of error being random might be due to imbalance is the samples for the folds.

# %%
review_raw = pd.read_csv('yelp_labelled.txt', delimiter= '\t', header=None)

review_raw.columns = ['message', 'sentement']

review_raw.head()
# Out:
#                                              message  sentement
# 0                           Wow... Loved this place.          1
# 1                                 Crust is not good.          0
# 2          Not tasty and the texture was just nasty.          0
# 3  Stopped by during the late May bank holiday of...          1
# 4  The selection on the menu was great and so wer...          1

# %%
k = review_raw[review_raw.sentement == 0].reset_index().drop('index', axis=1)
negFeatureslist = []

for i in k['message']:
    c = i.split(' ')
    for x in c:
        negFeatureslist.append(x)

#negFeatureslist = list(negFeatureslist)
negFeatureslist = ','.join([i for i in negFeatureslist if i.isalpha()])
negFeatureslist = negFeatureslist.split(',')

# %%
for key in negFeatureslist:
    # Note that we add spaces around the key so that we're getting the word,
    # not just pattern matching.
    review_raw[str(key)] = review_raw.message.str.contains(
        ' ' + str(key) + ' ',
        case=False
    )

data3 = review_raw[negFeatureslist]
target = review_raw['sentement']

print(cross_val_score(bnb, data2, target2, cv=10))

for i in range(0 , 10):
    datahold = data2.sample(n=100, replace=False)
    indexval = datahold.index.values.tolist()
    targethold = target2.take(indexval)
    
    X_train, X_test, y_train, y_test = train_test_split(datahold, targethold, test_size=0.2, random_state=20)
    
    y_pred = bnb.fit(datahold, targethold).predict(datahold)
    
    k = confusion_matrix(targethold, y_pred)
    
    print('With 20% Holdout: ' + str(100*bnb.fit(X_train, y_train).score(X_test, y_test)))
    #print('Testing sample: ' + str(100*bnb.fit(X_train, y_train).score(X_train, y_train)))
    print(k)
    print('percentage of true positive: ' + str(100*k[0][0]/(k[0][0] + k[0][1])))
    print('percentage of true negative: ' + str(100*k[1][1]/(k[1][0] + k[1][1])) + '\n')
# Out:
# [ 0.52  0.56  0.45  0.54  0.51  0.49  0.49  0.53  0.48  0.51]
# With 20% Holdout: 30.0
# [[49  3]
#  [38 10]]
# percentage of true positive: 94.2307692308
# percentage of true negative: 20.8333333333
#
# With 20% Holdout: 75.0
# [[21 26]
#  [ 1 52]]
# percentage of true positive: 44.6808510638
# percentage of true negative: 98.1132075472
#
# With 20% Holdout: 65.0
# [[13 33]
#  [ 1 53]]
# percentage of true positive: 28.2608695652
# percentage of true negative: 98.1481481481
#
# With 20% Holdout: 50.0
# [[48  1]
#  [44  7]]
# percentage of true positive: 97.9591836735
# percentage of true negative: 13.7254901961
#
# With 20% Holdout: 40.0
# [[51  0]
#  [43  6]]
# percentage of true positive: 100.0
# percentage of true negative: 12.2448979592
#
# With 20% Holdout: 40.0
# [[13 39]
#  [ 2 46]]
# percentage of true positive: 25.0
# percentage of true negative: 95.8333333333
#
# With 20% Holdout: 50.0
# [[15 35]
#  [ 4 46]]
# percentage of true positive: 30.0
# percentage of true negative: 92.0
#
# With 20% Holdout: 70.0
# [[54  3]
#  [37  6]]
# percentage of true positive: 94.7368421053
# percentage of true negative: 13.9534883721
#
# With 20% Holdout: 35.0
# [[12 36]
#  [ 6 46]]
# percentage of true positive: 25.0
# percentage of true negative: 88.4615384615
#
# With 20% Holdout: 45.0
# [[18 32]
#  [ 6 44]]
# percentage of true positive: 36.0
# percentage of true negative: 88.0

# %%
review_raw = pd.read_csv('yelp_labelled.txt', delimiter= '\t', header=None)

review_raw.columns = ['message', 'sentement']

review_raw.head()
# Out:
#                                              message  sentement
# 0                           Wow... Loved this place.          1
# 1                                 Crust is not good.          0
# 2          Not tasty and the texture was just nasty.          0
# 3  Stopped by during the late May bank holiday of...          1
# 4  The selection on the menu was great and so wer...          1

# %%
L = review_raw[review_raw.sentement == 1].reset_index().drop('index', axis=1)
posFeatureslist = []
for i in L['message']:
    c = i.split(' ')
    for x in c:
        posFeatureslist.append(x)
posFeatureslist
# Out:
# ['Wow...',
#  'Loved',
#  'this',
#  'place.',
#  'Stopped',
#  'by',
#  'during',
#  'the',
#  'late',
#  'May',
#  'bank',
#  'holiday',
#  'off',
#  'Rick',
#  'Steve',
#  'recommendation',
#  'and',
#  'loved',
#  'it.',
#  'The',
#  'selection',
#  'on',
#  'the',
#  'menu',
#  'was',
#  'great',
#  'and',
#  'so',
#  'were',
#  'the',
#  'prices.',
#  'The',
#  'fries',
#  'were',
#  'great',
#  'too.',
#  'A',
#  'great',
#  'touch.',
#  'Service',
#  'was',
#  'very',
#  'prompt.',
#  'I',
#  'tried',
#  'the',
#  'Cape',
#  'Cod',
#  'ravoli,',
#  'chicken,with',
#  'cranberry...mmmm!',
#  'Highly',
#  'recommended.',
#  'The',
#  'food,',
#  'amazing.',
#  'Service',
#  'is',
#  'also',
#  'cute.',
#  'I',
#  'could',
#  'care',
#  'less...',
#  'The',
#  'interior',
#  'is',
#  'just',
#  'beautiful.',
#  'So',
#  'they',
#  'performed.',
#  "That's",
#  'right....the',
#  'red',
#  'velvet',
#  'cake.....ohhh',
#  'this',
#  'stuff',
#  'is',
#  'so',
#  'good.',
#  'This',
#  'hole',
#  'in',
#  'the',
#  'wall',
#  'has',
#  'great',
#  'Mexican',
#  'street',
#  'tacos,',
#  'and',
#  'friendly',
#  'staff.',
#  'Also',
#  'there',
#  'are',
#  'combos',
#  'like',
#  'a',
#  'burger,',
#  'fries,',
#  'and',
#  'beer',
#  'for',
#  '23',
#  'which',
#  'is',
#  'a',
#  'decent',
#  'deal.',
#  'I',
#  'found',
#  'this',
#  'place',
#  'by',
#  'accident',
#  'and',
#  'I',
#  'could',
#  'not',
#  'be',
#  'happier.',
#  'Overall,',
#  'I',
#  'like',
#  'this',
#  'place',
#  'a',
#  'lot.',
#  'The',
#  'only',
#  'redeeming',
#  'quality',
#  'of',
#  'the',
#  'restaurant',
#  'was',
#  'that',
#  'it',
#  'was',
#  'very',
#  'inexpensive.',
#  'Ample',
#  'portions',
#  'and',
#  'good',
#  'prices.',
#  'My',
#  'first',
#  'visit',
#  'to',
#  'Hiro',
#  'was',
#  'a',
#  'delight!',
#  'The',
#  'shrimp',
#  'tender',
#  'and',
#  'moist.',
#  'On',
#  'a',
#  'positive',
#  'note,',
#  'our',
#  'server',
#  'was',
#  'very',
#  'attentive',
#  'and',
#  'provided',
#  'great',
#  'service.',
#  'The',
#  'only',
#  'thing',
#  'I',
#  'did',
#  'like',
#  'was',
#  'the',
#  'prime',
#  'rib',
#  'and',
#  'dessert',
#  'section.',
#  'The',
#  'burger',
#  'is',
#  'good',
#  'beef,',
#  'cooked',
#  'just',
#  'right.',
#  'If',
#  'you',
#  'want',
#  'a',
#  'sandwich',
#  'just',
#  'go',
#  'to',
#  'any',
#  'Firehouse!!!!!',
#  'My',
#  'side',
#  'Greek',
#  'salad',
#  'with',
#  'the',
#  'Greek',
#  'dressing',
#  'was',
#  'so',
#  'tasty,',
#  'and',
#  'the',
#  'pita',
#  'and',
#  'hummus',
#  'was',
#  'very',
#  'refreshing.',
#  'We',
#  'ordered',
#  'the',
#  'duck',
#  'rare',
#  'and',
#  'it',
#  'was',
#  'pink',
#  'and',
#  'tender',
#  'on',
#  'the',
#  'inside',
#  'with',
#  'a',
#  'nice',
#  'char',
#  'on',
#  'the',
#  'outside.',
#  'He',
#  'came',
#  'running',
#  'after',
#  'us',
#  'when',
#  'he',
#  'realized',
#  'my',
#  'husband',
#  'had',
#  'left',
#  'his',
#  'sunglasses',
#  'on',
#  'the',
#  'table.',
#  'Their',
#  'chow',
#  'mein',
#  'is',
#  'so',
#  'good!',
#  'The',
#  'portion',
#  'was',
#  'huge!',
#  'Loved',
#  'it...friendly',
#  'servers,',
#  'great',
#  'food,',
#  'wonderful',
#  'and',
#  'imaginative',
#  'menu.',
#  'The',
#  'salad',
#  'had',
#  'just',
#  'the',
#  'right',
#  'amount',
#  'of',
#  'sauce',
#  'to',
#  'not',
#  'over',
#  'power',
#  'the',
#  'scallop,',
#  'which',
#  'was',
#  'perfectly',
#  'cooked.',
#  'This',
#  'place',
#  'receives',
#  'stars',
#  'for',
#  'their',
#  'APPETIZERS!!!',
#  'The',
#  'cocktails',
#  'are',
#  'all',
#  'handmade',
#  'and',
#  'delicious.',
#  "We'd",
#  'definitely',
#  'go',
#  'back',
#  'here',
#  'again.',
#  'We',
#  'are',
#  'so',
#  'glad',
#  'we',
#  'found',
#  'this',
#  'place.',
#  'Great',
#  'food',
#  'and',
#  'service,',
#  'huge',
#  'portions',
#  'and',
#  'they',
#  'give',
#  'a',
#  'military',
#  'discount.',
#  'Always',
#  'a',
#  'great',
#  'time',
#  'at',
#  'Dos',
#  'Gringos!',
#  'Update.....went',
#  'back',
#  'for',
#  'a',
#  'second',
#  'time',
#  'and',
#  'it',
#  'was',
#  'still',
#  'just',
#  'as',
#  'amazing',
#  'A',
#  'great',
#  'way',
#  'to',
#  'finish',
#  'a',
#  'great.',
#  'The',
#  'deal',
#  'included',
#  '5',
#  'tastings',
#  'and',
#  '2',
#  'drinks,',
#  'and',
#  'Jeff',
#  'went',
#  'above',
#  'and',
#  'beyond',
#  'what',
#  'we',
#  'expected.',
#  '-',
#  'Really,',
#  'really',
#  'good',
#  'rice,',
#  'all',
#  'the',
#  'time.',
#  'The',
#  'sweet',
#  'potato',
#  'fries',
#  'were',
#  'very',
#  'good',
#  'and',
#  'seasoned',
#  'well.',
#  'Today',
#  'is',
#  'the',
#  'second',
#  'time',
#  "I've",
#  'been',
#  'to',
#  'their',
#  'lunch',
#  'buffet',
#  'and',
#  'it',
#  'was',
#  'pretty',
#  'good.',
#  'This',
#  'place',
#  'has',
#  'it!',
#  'I',
#  'love',
#  'the',
#  'Pho',
#  'and',
#  'the',
#  'spring',
#  'rolls',
#  'oh',
#  'so',
#  'yummy',
#  'you',
#  'have',
#  'to',
#  'try.',
#  'All',
#  'I',
#  'have',
#  'to',
#  'say',
#  'is',
#  'the',
#  'food',
#  'was',
#  'amazing!!!',
#  'Omelets',
#  'are',
#  'to',
#  'die',
#  'for!',
#  'Everything',
#  'was',
#  'fresh',
#  'and',
#  'delicious!',
#  "It's",
#  'like',
#  'a',
#  'really',
#  'sexy',
#  'party',
#  'in',
#  'your',
#  'mouth,',
#  'where',
#  "you're",
#  'outrageously',
#  'flirting',
#  'with',
#  'the',
#  'hottest',
#  'person',
#  'at',
#  'the',
#  'party.',
#  'Best',
#  'breakfast',
#  'buffet!!!',
#  'Will',
#  'be',
#  'back',
#  'again!',
#  'Food',
#  'arrived',
#  'quickly!',
#  'On',
#  'the',
#  'up',
#  'side,',
#  'their',
#  'cafe',
#  'serves',
#  'really',
#  'good',
#  'food.',
#  'Our',
#  'server',
#  'was',
#  'fantastic',
#  'and',
#  'when',
#  'he',
#  'found',
#  'out',
#  'the',
#  'wife',
#  'loves',
#  'roasted',
#  'garlic',
#  'and',
#  'bone',
#  'marrow,',
#  'he',
#  'added',
#  'extra',
#  'to',
#  'our',
#  'meal',
#  'and',
#  'another',
#  'marrow',
#  'to',
#  'go!',
#  'The',
#  'only',
#  'good',
#  'thing',
#  'was',
#  'our',
#  'waiter,',
#  'he',
#  'was',
#  'very',
#  'helpful',
#  'and',
#  'kept',
#  'the',
#  'bloddy',
#  "mary's",
#  'coming.',
#  'Best',
#  'Buffet',
#  'in',
#  'town,',
#  'for',
#  'the',
#  'price',
#  'you',
#  'cannot',
#  'beat',
#  'it.',
#  'I',
#  'LOVED',
#  'their',
#  'mussels',
#  'cooked',
#  'in',
#  'this',
#  'wine',
#  'reduction,',
#  'the',
#  'duck',
#  'was',
#  'tender,',
#  'and',
#  'their',
#  'potato',
#  'dishes',
#  'were',
#  'delicious.',
#  'This',
#  'is',
#  'one',
#  'of',
#  'the',
#  'better',
#  'buffets',
#  'that',
#  'I',
#  'have',
#  'been',
#  'to.',
#  'So',
#  'we',
#  'went',
#  'to',
#  'Tigerlilly',
#  'and',
#  'had',
#  'a',
#  'fantastic',
#  'afternoon!',
#  'The',
#  'food',
#  'was',
#  'delicious,',
#  'our',
#  'bartender',
#  'was',
#  'attentive',
#  'and',
#  'personable',
#  'AND',
#  'we',
#  'got',
#  'a',
#  'great',
#  'deal!',
#  'The',
#  'ambience',
#  'is',
#  'wonderful',
#  'and',
#  'there',
#  'is',
#  'music',
#  'playing.',
#  'Will',
#  'go',
#  'back',
#  'next',
#  'trip',
#  'out.',
#  'Sooooo',
#  'good!!',
#  'This',
#  'is',
#  'a',
#  'really',
#  'fantastic',
#  'Thai',
#  'restaurant',
#  'which',
#  'is',
#  'definitely',
#  'worth',
#  'a',
#  'visit.',
#  'Nice,',
#  'spicy',
#  'and',
#  'tender.',
#  'Good',
#  'prices.',
#  'Check',
#  'it',
#  'out.',
#  'Service',
#  'was',
#  'fine',
#  'and',
#  'the',
#  'waitress',
#  'was',
#  'friendly.',
#  'The',
#  'guys',
#  'all',
#  'had',
#  'steaks,',
#  'and',
#  'our',
#  'steak',
#  'loving',
#  'son',
#  'who',
#  'has',
#  'had',
#  'steak',
#  'at',
#  'the',
#  'best',
#  'and',
#  'worst',
#  'places',
#  'said',
#  'it',
#  'was',
#  'the',
#  'best',
#  'steak',
#  "he's",
#  'ever',
#  'eaten.',
#  'We',
#  'thought',
#  "you'd",
#  'have',
#  'to',
#  'venture',
#  'further',
#  'away',
#  'to',
#  'get',
#  'good',
#  'sushi,',
#  'but',
#  'this',
#  'place',
#  'really',
#  'hit',
#  'the',
#  'spot',
#  'that',
#  'night.',
#  'Phenomenal',
#  'food,',
#  'service',
#  'and',
#  'ambiance.',
#  'Definitely',
#  'worth',
#  'venturing',
#  'off',
#  'the',
#  'strip',
#  'for',
#  'the',
#  'pork',
#  'belly,',
#  'will',
#  'return',
#  'next',
#  'time',
#  "I'm",
#  'in',
#  'Vegas.',
#  'Penne',
#  'vodka',
#  'excellent!',
#  'They',
#  'have',
#  'a',
#  'good',
#  'selection',
#  'of',
#  'food',
#  'including',
#  'a',
#  'massive',
#  'meatloaf',
#  'sandwich,',
#  'a',
#  'crispy',
#  'chicken',
#  'wrap,',
#  'a',
#  'delish',
#  'tuna',
#  'melt',
#  'and',
#  'some',
#  'tasty',
#  'burgers.',
#  'Delicious',
#  'NYC',
#  'bagels,',
#  'good',
#  'selections',
#  'of',
#  'cream',
#  'cheese,',
#  'real',
#  'Lox',
#  'with',
#  'capers',
#  'even.',
#  'Great',
#  'Subway,',
#  'in',
#  'fact',
#  "it's",
#  'so',
#  'good',
#  'when',
#  'you',
#  'come',
#  'here',
#  'every',
#  'other',
#  'Subway',
#  'will',
#  'not',
#  'meet',
#  'your',
#  'expectations.',
#  'I',
#  'had',
#  'a',
#  'seriously',
#  'solid',
#  'breakfast',
#  'here.',
#  'This',
#  'is',
#  'one',
#  'of',
#  'the',
#  'best',
#  'bars',
#  'with',
#  'food',
#  'in',
#  'Vegas.',
#  'My',
#  'drink',
#  'was',
#  'never',
#  'empty',
#  'and',
#  'he',
#  'made',
#  'some',
#  'really',
#  'great',
#  'menu',
#  'suggestions.',
#  'Nice',
#  'blanket',
#  'of',
#  'moz',
#  'over',
#  'top',
#  'but',
#  'i',
#  'feel',
#  'like',
#  'this',
#  'was',
#  'done',
#  'to',
#  'cover',
#  'up',
#  'the',
#  'subpar',
#  'food.',
#  'The',
#  'bathrooms',
#  'are',
#  'clean',
#  'and',
#  'the',
#  'place',
#  'itself',
#  'is',
#  'well',
#  'decorated.',
#  'My',
#  'fiancé',
#  'and',
#  'I',
#  'came',
#  'in',
#  'the',
#  'middle',
#  'of',
#  'the',
#  'day',
#  'and',
#  'we',
#  'were',
#  'greeted',
#  'and',
#  'seated',
#  'right',
#  'away.',
#  'This',
#  'is',
#  'a',
#  'great',
#  'restaurant',
#  'at',
#  'the',
#  'Mandalay',
#  'Bay.',
#  'Some',
#  'highlights',
#  ':',
#  'Great',
#  'quality',
#  'nigiri',
#  'here!',
#  'the',
#  'staff',
#  'is',
#  'friendly',
#  'and',
#  'the',
#  'joint',
#  'is',
#  'always',
#  'clean.',
#  'this',
#  'was',
#  'a',
#  'different',
#  'cut',
#  'than',
#  'the',
#  'piece',
#  'the',
#  'other',
#  'day',
#  'but',
#  'still',
#  'wonderful',
#  'and',
#  'tender',
#  's',
#  'well',
#  'as',
#  'well',
#  'flavored.',
#  'I',
#  'ordered',
#  'the',
#  'Voodoo',
#  'pasta',
#  'and',
#  'it',
#  'was',
#  'the',
#  'first',
#  'time',
#  "I'd",
#  'had',
#  'really',
#  'excellent',
#  'pasta',
#  'since',
#  'going',
#  'gluten',
#  'free',
#  'several',
#  'years',
#  'ago.',
#  'this',
#  'place',
#  'is',
#  'good.',
#  'I',
#  'was',
#  'seated',
#  'immediately.',
#  'Their',
#  'menu',
#  'is',
#  'diverse,',
#  'and',
#  'reasonably',
#  'priced.',
#  'Restaurant',
#  'is',
#  'always',
#  'full',
#  'but',
#  'never',
#  'a',
#  'wait.',
#  'DELICIOUS!!',
#  'This',
#  'place',
#  'is',
#  'hands-down',
#  'one',
#  'of',
#  'the',
#  'best',
#  'places',
#  'to',
#  'eat',
#  'in',
#  'the',
#  'Phoenix',
#  'metro',
#  'area.',
#  'Bacon',
#  'is',
#  'hella',
#  'salty.',
#  'This',
#  'really',
#  'is',
#  'how',
#  'Vegas',
#  'fine',
#  'dining',
#  'used',
#  'to',
#  'be,',
#  'right',
#  'down',
#  'to',
#  'the',
#  'menus',
#  'handed',
#  'to',
#  ...]

# %%
posFeatureslist = ','.join([i for i in posFeatureslist if i.isalpha()])
posFeatureslist
# Out:
# 'Loved,this,Stopped,by,during,the,late,May,bank,holiday,off,Rick,Steve,recommendation,and,loved,The,selection,on,the,menu,was,great,and,so,were,the,The,fries,were,great,A,great,Service,was,very,I,tried,the,Cape,Cod,Highly,The,Service,is,also,I,could,care,The,interior,is,just,So,they,red,velvet,this,stuff,is,so,This,hole,in,the,wall,has,great,Mexican,street,and,friendly,Also,there,are,combos,like,a,and,beer,for,which,is,a,decent,I,found,this,place,by,accident,and,I,could,not,be,I,like,this,place,a,The,only,redeeming,quality,of,the,restaurant,was,that,it,was,very,Ample,portions,and,good,My,first,visit,to,Hiro,was,a,The,shrimp,tender,and,On,a,positive,our,server,was,very,attentive,and,provided,great,The,only,thing,I,did,like,was,the,prime,rib,and,dessert,The,burger,is,good,cooked,just,If,you,want,a,sandwich,just,go,to,any,My,side,Greek,salad,with,the,Greek,dressing,was,so,and,the,pita,and,hummus,was,very,We,ordered,the,duck,rare,and,it,was,pink,and,tender,on,the,inside,with,a,nice,char,on,the,He,came,running,after,us,when,he,realized,my,husband,had,left,his,sunglasses,on,the,Their,chow,mein,is,so,The,portion,was,Loved,great,wonderful,and,imaginative,The,salad,had,just,the,right,amount,of,sauce,to,not,over,power,the,which,was,perfectly,This,place,receives,stars,for,their,The,cocktails,are,all,handmade,and,definitely,go,back,here,We,are,so,glad,we,found,this,Great,food,and,huge,portions,and,they,give,a,military,Always,a,great,time,at,Dos,back,for,a,second,time,and,it,was,still,just,as,amazing,A,great,way,to,finish,a,The,deal,included,tastings,and,and,Jeff,went,above,and,beyond,what,we,really,good,all,the,The,sweet,potato,fries,were,very,good,and,seasoned,Today,is,the,second,time,been,to,their,lunch,buffet,and,it,was,pretty,This,place,has,I,love,the,Pho,and,the,spring,rolls,oh,so,yummy,you,have,to,All,I,have,to,say,is,the,food,was,Omelets,are,to,die,Everything,was,fresh,and,like,a,really,sexy,party,in,your,where,outrageously,flirting,with,the,hottest,person,at,the,Best,breakfast,Will,be,back,Food,arrived,On,the,up,their,cafe,serves,really,good,Our,server,was,fantastic,and,when,he,found,out,the,wife,loves,roasted,garlic,and,bone,he,added,extra,to,our,meal,and,another,marrow,to,The,only,good,thing,was,our,he,was,very,helpful,and,kept,the,bloddy,Best,Buffet,in,for,the,price,you,cannot,beat,I,LOVED,their,mussels,cooked,in,this,wine,the,duck,was,and,their,potato,dishes,were,This,is,one,of,the,better,buffets,that,I,have,been,So,we,went,to,Tigerlilly,and,had,a,fantastic,The,food,was,our,bartender,was,attentive,and,personable,AND,we,got,a,great,The,ambience,is,wonderful,and,there,is,music,Will,go,back,next,trip,Sooooo,This,is,a,really,fantastic,Thai,restaurant,which,is,definitely,worth,a,spicy,and,Good,Check,it,Service,was,fine,and,the,waitress,was,The,guys,all,had,and,our,steak,loving,son,who,has,had,steak,at,the,best,and,worst,places,said,it,was,the,best,steak,ever,We,thought,have,to,venture,further,away,to,get,good,but,this,place,really,hit,the,spot,that,Phenomenal,service,and,Definitely,worth,venturing,off,the,strip,for,the,pork,will,return,next,time,in,Penne,vodka,They,have,a,good,selection,of,food,including,a,massive,meatloaf,a,crispy,chicken,a,delish,tuna,melt,and,some,tasty,Delicious,NYC,good,selections,of,cream,real,Lox,with,capers,Great,in,fact,so,good,when,you,come,here,every,other,Subway,will,not,meet,your,I,had,a,seriously,solid,breakfast,This,is,one,of,the,best,bars,with,food,in,My,drink,was,never,empty,and,he,made,some,really,great,menu,Nice,blanket,of,moz,over,top,but,i,feel,like,this,was,done,to,cover,up,the,subpar,The,bathrooms,are,clean,and,the,place,itself,is,well,My,fiancé,and,I,came,in,the,middle,of,the,day,and,we,were,greeted,and,seated,right,This,is,a,great,restaurant,at,the,Mandalay,Some,highlights,Great,quality,nigiri,the,staff,is,friendly,and,the,joint,is,always,this,was,a,different,cut,than,the,piece,the,other,day,but,still,wonderful,and,tender,s,well,as,well,I,ordered,the,Voodoo,pasta,and,it,was,the,first,time,h ...

# %%
posFeatureslist = posFeatureslist.split(',')
len(posFeatureslist)
# Out:
# 4302

# %%
for key in posFeatureslist:
    # Note that we add spaces around the key so that we're getting the word,
    # not just pattern matching.
    review_raw[str(key)] = review_raw.message.str.contains(
        ' ' + str(key) + ' ',
        case=False
    )

data3 = review_raw[posFeatureslist]
target = review_raw['sentement']

print(cross_val_score(bnb, data2, target2, cv=10))

for i in range(0 , 10):
    datahold = data2.sample(n=100, replace=False)
    indexval = datahold.index.values.tolist()
    targethold = target2.take(indexval)
    
    X_train, X_test, y_train, y_test = train_test_split(datahold, targethold, test_size=0.2, random_state=20)
    
    y_pred = bnb.fit(datahold, targethold).predict(datahold)
    
    k = confusion_matrix(targethold, y_pred)
    
    print('With 20% Holdout: ' + str(100*bnb.fit(X_train, y_train).score(X_test, y_test)))
    #print('Testing sample: ' + str(100*bnb.fit(X_train, y_train).score(X_train, y_train)))
    print(k)
    print('percentage of true positive: ' + str(100*k[0][0]/(k[0][0] + k[0][1])))
    print('percentage of true negative: ' + str(100*k[1][1]/(k[1][0] + k[1][1])) + '\n')
# Out:
# [ 0.52  0.56  0.45  0.54  0.51  0.49  0.49  0.53  0.48  0.51]
# With 20% Holdout: 50.0
# [[50  3]
#  [42  5]]
# percentage of true positive: 94.3396226415
# percentage of true negative: 10.6382978723
#
# With 20% Holdout: 45.0
# [[47  6]
#  [36 11]]
# percentage of true positive: 88.679245283
# percentage of true negative: 23.4042553191
#
# With 20% Holdout: 55.0
# [[23 29]
#  [ 5 43]]
# percentage of true positive: 44.2307692308
# percentage of true negative: 89.5833333333
#
# With 20% Holdout: 45.0
# [[17 35]
#  [ 6 42]]
# percentage of true positive: 32.6923076923
# percentage of true negative: 87.5
#
# With 20% Holdout: 45.0
# [[53  3]
#  [35  9]]
# percentage of true positive: 94.6428571429
# percentage of true negative: 20.4545454545
#
# With 20% Holdout: 45.0
# [[57  3]
#  [35  5]]
# percentage of true positive: 95.0
# percentage of true negative: 12.5
#
# With 20% Holdout: 40.0
# [[ 3 45]
#  [ 0 52]]
# percentage of true positive: 6.25
# percentage of true negative: 100.0
#
# With 20% Holdout: 50.0
# [[ 7 34]
#  [ 1 58]]
# percentage of true positive: 17.0731707317
# percentage of true negative: 98.3050847458
#
# With 20% Holdout: 50.0
# [[13 35]
#  [ 4 48]]
# percentage of true positive: 27.0833333333
# percentage of true negative: 92.3076923077
#
# With 20% Holdout: 70.0
# [[18 31]
#  [ 2 49]]
# percentage of true positive: 36.7346938776
# percentage of true negative: 96.0784313725

# %%
samewordlist = []
diffwordlist = []
for i in negFeatureslist:
    for x in posFeatureslist:
        if i == x:
            samewordlist.append(i)
            break

new_list = [key for key in negFeatureslist if key not in samewordlist]

# %%
for key in new_list:
    # Note that we add spaces around the key so that we're getting the word,
    # not just pattern matching.
    review_raw[str(key)] = review_raw.message.str.contains(
        ' ' + str(key) + ' ',
        case=False
    )

data3 = review_raw[new_list]
target = review_raw['sentement']

print(cross_val_score(bnb, data2, target2, cv=10))

for i in range(0 , 10):
    datahold = data2.sample(n=100, replace=False)
    indexval = datahold.index.values.tolist()
    targethold = target2.take(indexval)
    
    X_train, X_test, y_train, y_test = train_test_split(datahold, targethold, test_size=0.2, random_state=20)
    
    y_pred = bnb.fit(datahold, targethold).predict(datahold)
    
    k = confusion_matrix(targethold, y_pred)
    
    print('With 20% Holdout: ' + str(100*bnb.fit(X_train, y_train).score(X_test, y_test)))
    #print('Testing sample: ' + str(100*bnb.fit(X_train, y_train).score(X_train, y_train)))
    print(k)
    print('percentage of true positive: ' + str(100*k[0][0]/(k[0][0] + k[0][1])))
    print('percentage of true negative: ' + str(100*k[1][1]/(k[1][0] + k[1][1])) + '\n')
# Out:
# [ 0.52  0.56  0.45  0.54  0.51  0.49  0.49  0.53  0.48  0.51]
# With 20% Holdout: 60.0
# [[11 39]
#  [ 3 47]]
# percentage of true positive: 22.0
# percentage of true negative: 94.0
#
# With 20% Holdout: 45.0
# [[21 34]
#  [ 7 38]]
# percentage of true positive: 38.1818181818
# percentage of true negative: 84.4444444444
#
# With 20% Holdout: 40.0
# [[47  2]
#  [40 11]]
# percentage of true positive: 95.9183673469
# percentage of true negative: 21.568627451
#
# With 20% Holdout: 30.0
# [[11 39]
#  [ 4 46]]
# percentage of true positive: 22.0
# percentage of true negative: 92.0
#
# With 20% Holdout: 45.0
# [[ 8 37]
#  [ 2 53]]
# percentage of true positive: 17.7777777778
# percentage of true negative: 96.3636363636
#
# With 20% Holdout: 45.0
# [[14 30]
#  [ 7 49]]
# percentage of true positive: 31.8181818182
# percentage of true negative: 87.5
#
# With 20% Holdout: 55.0
# [[ 5 39]
#  [ 2 54]]
# percentage of true positive: 11.3636363636
# percentage of true negative: 96.4285714286
#
# With 20% Holdout: 55.0
# [[55  0]
#  [42  3]]
# percentage of true positive: 100.0
# percentage of true negative: 6.66666666667
#
# With 20% Holdout: 45.0
# [[52  0]
#  [42  6]]
# percentage of true positive: 100.0
# percentage of true negative: 12.5
#
# With 20% Holdout: 60.0
# [[ 7 36]
#  [ 1 56]]
# percentage of true positive: 16.2790697674
# percentage of true negative: 98.2456140351

# %%
new_list
# Out:
# ['Crust',
#  'angry',
#  'damn',
#  'Honeslty',
#  'THAT',
#  'rubber',
#  'ahead',
#  'under',
#  'ended',
#  'wayyy',
#  'disgusted',
#  'human',
#  'shocked',
#  'signs',
#  'indicate',
#  'cash',
#  'slow',
#  'let',
#  'alone',
#  'Burrittos',
#  'asked',
#  'Took',
#  'hour',
#  'tables',
#  'Luke',
#  'sever',
#  'totally',
#  'final',
#  'seems',
#  'grab',
#  'bite',
#  'familiar',
#  'pub',
#  'yourself',
#  'favor',
#  'look',
#  'Poor',
#  'stupid',
#  'drag',
#  'into',
#  'establishment',
#  'Hard',
#  'judge',
#  'whether',
#  'these',
#  'grossed',
#  'melted',
#  'styrofoam',
#  'fear',
#  'Frozen',
#  'pucks',
#  'behind',
#  'bad',
#  'damn',
#  'horrible',
#  'attitudes',
#  'towards',
#  'talk',
#  'customers',
#  'Heart',
#  'Attack',
#  'Grill',
#  'excuse',
#  'strings',
#  'ripped',
#  'banana',
#  'petrified',
#  'refill',
#  'water',
#  'struggle',
#  'wave',
#  'apparently',
#  'salt',
#  'batter',
#  'took',
#  'min',
#  'chocolate',
#  'guess',
#  'should',
#  'known',
#  'use',
#  'common',
#  'scallop',
#  'appalling',
#  'value',
#  'Bad',
#  'Customer',
#  'cheated',
#  'wasting',
#  'Rice',
#  'Coming',
#  'experiencing',
#  'underwhelming',
#  'relationship',
#  'parties',
#  'break',
#  'smelled',
#  'grease',
#  'trap',
#  'others',
#  'turkey',
#  'pan',
#  'cakes',
#  'everyone',
#  'raving',
#  'sugary',
#  'disaster',
#  'tailored',
#  'palate',
#  'six',
#  'poor',
#  'batter',
#  'ratio',
#  'tenders',
#  'largely',
#  'disappointing',
#  'Hard',
#  'Rock',
#  'Casino',
#  'WILL',
#  'NEVER',
#  'EVER',
#  'STEP',
#  'FORWARD',
#  'IN',
#  'IT',
#  'bye',
#  'bye',
#  'REAL',
#  'honest',
#  'Yama',
#  'passed',
#  'between',
#  'ordering',
#  'Kind',
#  'hard',
#  'mess',
#  'Although',
#  'look',
#  'sound',
#  'actual',
#  'managed',
#  'blandest',
#  'Worst',
#  'Host',
#  'lack',
#  'liking',
#  'number',
#  'reasons',
#  'waste',
#  'bad',
#  'overpriced',
#  'mediocre',
#  'management',
#  'extremely',
#  'rude',
#  'restaurants',
#  'weekend',
#  'rarely',
#  'disappointed',
#  'bamboo',
#  'shoots',
#  'extremely',
#  'slow',
#  'servers',
#  'slow',
#  'watched',
#  'attention',
#  'tables',
#  'ignore',
#  'waited',
#  'forty',
#  'five',
#  'minutes',
#  'Crostini',
#  'leftover',
#  'relocated',
#  'Avoid',
#  'looking',
#  'spinach',
#  'avocado',
#  'ingredients',
#  'sad',
#  'literally',
#  'zero',
#  'Perhaps',
#  'caught',
#  'judging',
#  'inspired',
#  'leaves',
#  'literally',
#  'minutes',
#  'asking',
#  'flavor',
#  'totally',
#  'overcooked',
#  'charcoal',
#  'send',
#  'verge',
#  'having',
#  'heart',
#  'dressed',
#  'probably',
#  'expected',
#  'sucked',
#  'gyros',
#  'voted',
#  'dog',
#  'Valley',
#  'readers',
#  'live',
#  'Fridays',
#  'totally',
#  'insulted',
#  'lived',
#  'stepped',
#  'foot',
#  'into',
#  'WORST',
#  'EXPERIENCE',
#  'Must',
#  'bug',
#  'showed',
#  'given',
#  'bug',
#  'climbing',
#  'waiting',
#  'her',
#  'Soggy',
#  'Which',
#  'shower',
#  'unless',
#  'mind',
#  'nude',
#  'everyone',
#  'Bussell',
#  'Filet',
#  'ALL',
#  'needed',
#  'salt',
#  'none',
#  'Hopefully',
#  'bodes',
#  'business',
#  'cook',
#  'either',
#  'flavor',
#  'bad',
#  'then',
#  'drunk',
#  'Ordered',
#  'cheeseburger',
#  'single',
#  'patty',
#  'falling',
#  'apart',
#  'possible',
#  'zero',
#  'descriptions',
#  'yum',
#  'NONE',
#  'sauces',
#  'rolled',
#  'eyes',
#  'Horrible',
#  'waste',
#  'busy',
#  'building',
#  'FREEZING',
#  'reviewer',
#  'took',
#  'minutes',
#  'Based',
#  'effort',
#  'show',
#  'gratitude',
#  'business',
#  'privileged',
#  'parents',
#  'most',
#  'complaints',
#  'silently',
#  'given',
#  'godfathers',
#  'zero',
#  'tough',
#  'short',
#  'recall',
#  'charged',
#  'self',
#  'proclaimed',
#  'coffee',
#  'wildly',
#  'dedicated',
#  'boba',
#  'tea',
#  'Jenni',
#  'mac',
#  'bland',
#  'stinks',
#  'waited',
#  'Things',
#  'burned',
#  'waited',
#  'hour',
#  'hate',
#  'disagree',
#  'fellow',
#  'disappointed',
#  'Waited',
#  'hours',
#  'either',
#  'later',
#  'why',
#  'live',
#  'disappointed',
#  'convenient',
#  'Before',
#  'why',
#  'star',
#  'rating',
#  'please',
#  'third',
#  'writing',
#  'Please',
#  'chip',
#  'probably',
#  'count',
#  'box',
#  'probably',
#  'greedy',
#  'corporation',
#  'NEVER',
#  'dime',
#  'passed',
#  'atrocious',
#  'She',
#  'English',
#  'muffin',
#  'bus',
#  'boy',
#  'hand',
#  'basically',
#  'figured',
#  'joke',
#  'mind',
#  'making',
#  'publicly',
#  'loudly',
#  'downside',
#  'without',
#  'doubt',
#  'seen',
#  'immediately',
#  'sick',
#  'bites',
#  'servers',
#  'honor',
#  'Hut',
#  'location',
#  'Seat',
#  'covers',
#  'replenished',
#  'plain',
#  'spaghetti',
#  'probably',
#  'seen',
#  'minutes',
#  'finally',
#  'min',
#  'Gordon',
#  'Steak',
#  'shall',
#  'sharply',
#  'avoid',
#  'offered',
#  'turn',
#  'doubt',
#  'unless',
#  'else',
#  'wasting',
#  'Bisque',
#  'soup',
#  'stomach',
#  'ache',
#  'sick',
#  'rest',
#  'dropped',
#  'beans',
#  'rice',
#  'mediocre',
#  'took',
#  'money',
#  'outta',
#  'RUDE',
#  'INCONSIDERATE',
#  'says',
#  'hi',
#  'WILL',
#  'NEVER',
#  'EVER',
#  'BACK',
#  'HAVE',
#  'TOLD',
#  'MANY',
#  'PEOPLE',
#  'WHAT',
#  'HAD',
#  'unless',
#  'car',
#  'breaks',
#  'front',
#  'star',
#  'probably',
#  'Ians',
#  'simply',
#  'disappointed',
#  'accountant',
#  'Left',
#  'TOTAL',
#  'WASTE',
#  'OF',
#  'bad',
#  'Gave',
#  'trying',
#  'crust',
#  'But',
#  'grossed',
#  'pile',
#  'green',
#  'bird',
#  'hours',
#  'operation',
#  'mistake',
#  'Waiter',
#  'Strike',
#  'wants',
#  'Ordered',
#  'appetizer',
#  'took',
#  'minutes',
#  'then',
#  'awkward',
#  'gristle',
#  'business',
#  'dollars',
#  'Nothing',
#  'Sauce',
#  'anytime',
#  'connoisseur',
#  'difference',
#  'between',
#  'bad',
#  'certainly',
#  'bad',
#  'contained',
#  'driest',
#  'anytime',
#  'due',
#  'took',
#  'minutes',
#  'then',
#  'minutes',
#  'forgetting',
#  'note',
#  'ventilation',
#  'use',
#  'waste',
#  'Total',
#  'rather',
#  'Camelback',
#  'Shop',
#  'Cartel',
#  'asked',
#  'without',
#  'Seafood',
#  'limited',
#  'boiled',
#  'crab',
#  'legs',
#  'crab',
#  'legs',
#  'dont',
#  'long',
#  'attached',
#  'gas',
#  'rarely',
#  'Worse',
#  'humiliated',
#  'worker',
#  'front',
#  'horrible',
#  'name',
#  'then',
#  'tragedy',
#  'rather',
#  'airline',
#  'Overall',
#  'gyro',
#  'basically',
#  'lettuce',
#  'Terrible',
#  'Thoroughly',
#  'unhealthy',
#  'might',
#  'delivery',
#  'man',
#  'word',
#  'apology',
#  'minutes',
#  'Terrible',
#  'zero',
#  'zero',
#  'Worst',
#  'martini',
#  'waited',
#  'thirty',
#  'minutes',
#  'vacant',
#  'tables',
#  'strangers',
#  'hair',
#  'guess',
#  'maybe',
#  'particular',
#  'location',
#  'restaurants',
#  'AVOID',
#  'THIS',
#  'suffers',
#  'trying',
#  'hard',
#  'bland',
#  'vinegrette',
#  'baby',
#  'greens',
#  'hearts',
#  'recommended',
#  'servers',
#  'forth',
#  'AN',
#  'consider',
#  'location',
#  'needs',
#  'complete',
#  'witnessed',
#  'her',
#  'poor',
#  'management',
#  'towards',
#  'guests',
#  'Waited',
#  'waited',
#  'chewy',
#  'swung',
#  'deeply',
#  'Boy',
#  'sucker',
#  'Over',
#  'look',
#  'else',
#  'car',
#  'waited',
#  'minutes',
#  'hate',
#  'cheap',
#  'kids',
#  'play',
#  'extremely',
#  'pale',
#  'color',
#  'instead',
#  'NO',
#  'driest',
#  'damn',
#  'sitting',
#  'fairly',
#  'ended',
#  'waiting',
#  'minutes',
#  'minutes',
#  'wanted',
#  'OWNERS',
#  'REALLY',
#  'REALLY',
#  'quit',
#  'soooooo',
#  'cheap',
#  'let',
#  'wrap',
#  'freaking',
#  'papers',
#  'ago',
#  'reheated',
#  'wedges',
#  'cold',
#  'anytime',
#  'Bloody',
#  'Despite',
#  'hard',
#  'rate',
#  'its',
#  'actually',
#  'thru',
#  'means',
#  'hour',
#  'somehow',
#  'end',
#  'luck',
#  'rude',
#  'focused',
#  'Any',
#  'grandmother',
#  'asked',
#  'ignored',
#  'hostess',
#  'Same',
#  'him',
#  'drastically',
#  'Ordered',
#  'Tried',
#  'waiting',
#  'hour',
#  'greatest',
#  'Maybe',
#  'cold',
#  'somewhat',
#  'fails',
#  'bad',
#  'average',
#  'anytime',
#  'Disappointed',
#  'Big',
#  'flavor',
#  'poorly',
#  'rice',
#  'dry',
#  'Google',
#  'mediocre',
#  'imagine',
#  'Smashburger',
#  'dont',
#  'lover',
#  'avoid',
#  'plantains',
#  'slow',
#  'Your',
#  'spends',
#  'talking',
#  'themselves',
#  'Total',
#  'probably',
#  'expected',
#  'Needless',
#  'should',
#  'dripping',
#  'mostly',
#  'Strip',
#  'hospitality',
#  'industry',
#  'Paradise',
#  'Valley',
#  'refrained',
#  'recommending',
#  'Cibo',
#  'mean',
#  'famous',
#  'reading',
#  'please',
#  'Tonight',
#  'Elk',
#  'Filet',
#  'classics',
#  'sorely',
#  'disappointed',
#  'FLY',
#  'apple',
#  'barely',
#  'sitting',
#  'waiting',
#  'Bar',
#  'Edinburgh',
#  'establishment',
#  'Probably',
#  'barely',
#  'touched',
#  'long',
#  'stood',
#  'long',
#  'begin',
#  'awkwardly',
#  'opened',
#  'watched',
#  'smaller',
#  'management',
#  'attitudes',
#  'grow',
#  'Main',
#  'crowd',
#  'older',
#  'mid',
#  'minutes',
#  'longer',
#  'poor',
#  'thats',
#  'shoe',
#  'But',
#  'Tasted',
#  'sashimi',
#  'poor',
#  'soggy',
#  'its',
#  'traditional',
#  'Hunan',
#  'bother',
#  'slow',
#  'frozen',
#  'margaritas',
#  'WAY',
#  'sugary',
#  'restaraunt',
#  'smells',
#  'dirty',
#  'market',
#  'veal',
#  'Bland',
#  'flavorless',
#  'describing',
#  'barely',
#  'tepid',
#  'fan',
#  'arrives',
#  'Paying',
#  'dog',
#  'looks',
#  'Wienerschnitzel',
#  'idea',
#  'brother',
#  'law',
#  'works',
#  'same',
#  'guess',
#  'sick',
#  'Mediocre',
#  'Why',
#  'these',
#  'sad',
#  'hopes',
#  'charcoal',
#  'unfortunately',
#  'single',
#  'employee',
#  'OK',
#  'needed',
#  'water',
#  'refill',
#  'finally',
#  'negligent',
#  'needs',
#  'suggest',
#  'terrible',
#  'consistent',
#  'worse',
#  'worse',
#  'officially',
#  'should',
#  'honestly',
#  'blown',
#  'But',
#  'Do',
#  'waste',
#  'money',
#  'Awful',
#  'rather',
#  'fair',
#  'Kabuki',
#  'Do',
#  'yourself',
#  'favor',
#  'poor',
#  'average',
#  'paid',
#  'terrible',
#  'bland',
#  'surprised',
#  'article',
#  'read',
#  'focused',
#  'spices',
#  'overpriced',
#  'fucking',
#  'bucks',
#  'dirty',
#  'oysters',
#  'qualified',
#  'version',
#  'these',
#  'foods',
#  'Bad',
#  'low',
#  'tolerance',
#  'rude',
#  'wash',
#  'probably',
#  'Wife',
#  'hated',
#  'her',
#  'fella',
#  'huevos',
#  'rancheros',
#  'look',
#  'probably',
#  'Worst',
#  'cold',
#  'watched',
#  'prepare',
#  'BARE',
#  'deep',
#  'college',
#  'cooking',
#  'class',
#  'slow',
#  'started',
#  'editing',
#  'besides',
#  'Weird',
#  'hardly',
#  'bagels',
#  'grocery',
#  'doughy',
#  'six',
#  'inch',
#  'long',
#  'wire',
#  'Albondigas',
#  'soup',
#  'tomato',
#  'soup',
#  'frozen',
#  'three',
#  'occasions',
#  'asked',
#  'medium',
#  'three',
#  'bloodiest',
#  'bites',
#  'refused',
#  'extremely',
#  'minutes',
#  'allergy',
#  'warnings',
#  'clue',
#  'meals',
#  'contain',
#  'Pricing',
#  'concern',
#  'Mellow',
#  'Worst',
#  'unprofessional',
#  'rude',
#  'loyal',
#  'Spend',
#  'money',
#  'Bellagio',
#  'disappointing',
#  'elsewhere',
#  'unexperienced',
#  'employees',
#  'chickens',
#  'heads',
#  'insulted',
#  'talk',
#  'judge',
#  'human',
#  'call',
#  'yourself',
#  'steakhouse',
#  'properly',
#  'cook',
#  'concept',
#  'guacamole',
#  'poisoning',
#  'batch',
#  'thinking',
#  'yay',
#  'SHOULD',
#  'Christmas',
#  'Eve',
#  'remember',
#  'biggest',
#  'fail',
#  'entire',
#  'Needless',
#  'anytime',
#  'RI',
#  'style',
#  'calamari',
#  'barely',
#  'barely',
#  'stomach',
#  'business',
#  'lost',
#  'heart',
#  'took',
#  'her',
#  'forever',
#  'asked',
#  'ones',
#  'scene',
#  'restaurants',
#  'lost',
#  'Disappointing',
#  'par',
#  'mediocre',
#  'downright',
#  'terrible',
#  'then',
#  'WAAAAAAyyyyyyyyyy',
#  'rated',
#  'fairly',
#  'simply',
#  'lacked',
#  'sangria',
#  'glass',
#  'bother',
#  'brisket',
#  'building',
#  'seems',
#  'Probably',
#  'hurry',
#  'slow',
#  'stretch',
#  'cashew',
#  'bland',
#  'chipolte',
#  'ranch',
#  'dipping',
#  'sause',
#  'seemed',
#  'watered',
#  'lacked',
#  'VERY',
#  'horrible',
#  'Maybe',
#  'Vegetarian',
#  'average',
#  'busy',
#  'tables',
#  'dirty',
#  'workers',
#  'douchey',
#  'indoor',
#  'garden',
#  'tea',
#  'spotty',
#  'neither',
#  'But',
#  'then',
#  'Then',
#  'disappointment',
#  'disappointment',
#  'apologize',
#  'bad',
#  'reason',
#  'fill',
#  'binge',
#  'drinking',
#  'carbs',
#  'profound',
#  'smoke',
#  'break',
#  'solidify',
#  'combo',
#  'ala',
#  'She',
#  'disappointed',
#  'although',
#  'blame',
#  'needs',
#  'placed',
#  'her',
#  'rave',
#  'reviews',
#  'Del',
#  'Taco',
#  'nasty',
#  'should',
#  'avoided',
#  'NOT',
#  'hard',
#  'But',
#  'Hell',
#  'gotten',
#  'services',
#  'immediately',
#  'wanted',
#  'talk',
#  'talk',
#  'doing',
#  'shots',
#  ...]
